# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd
# Out:
# 'C:\\Users\\MAVERICK\\OneDrive\\Desktop\\New folder\\HiCouselor\\playstoreliveproj'

# %%
reviews=pd.read_csv('playstore_reviews.csv')
reviews
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
reviews.shape
# Out:
# (64295, 5)

# %%
reviews.App.value_counts()
# Out:
# Angry Birds Classic                                  320
# CBS Sports App - Scores, News, Stats & Watch Live    320
# Bowmasters                                           320
# 8 Ball Pool                                          300
# Helix Jump                                           300
#                                                     ...
# Easy Healthy Recipes                                  31
# Dresses Ideas & Fashions +3000                        31
# Detector de Radares Gratis                            31
# Easy Hair Style Design                                30
# Drawing Clothes Fashion Ideas                         30
# Name: App, Length: 1074, dtype: int64

# %%
reviews.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %% [markdown]
# ## 11 -Get the number of reviews having positive sentiment and number of reviews having negative sentiment for the app 10 best foods for you and compare them.

# %%
len(reviews[(reviews['App']=="10 Best Foods for You") & (reviews['Sentiment']=='Positive')])
# Out:
# 162

# %%
len(reviews[(reviews['App']=="10 Best Foods for You") & (reviews['Sentiment']=='Negative')])
# Out:
# 10

# %%
# So he can say that there are 162 postive reviews about the app "10 Best Foods for You" and only 10 negative reviews.

# %% [markdown]
# ## 12- Which comments of ASUS SuperNote have sentiment polarity and sentiment subjectivity both as 1?

# %%
reviews[(reviews['App']=="ASUS SuperNote") & (reviews['Sentiment_Polarity']==1) & (reviews['Sentiment_Subjectivity']==1)]
# Out:
#                  App Translated_Review Sentiment  Sentiment_Polarity  \
# 3391  ASUS SuperNote       Awesome!!!!  Positive                 1.0
#
#       Sentiment_Subjectivity
# 3391                     1.0

# %% [markdown]
# ## 13 - Get all the neutral sentiment reviews for the app Abs Training-Burn belly fat.

# %%
reviews[(reviews['App']=="Abs Training-Burn belly fat") & (reviews['Sentiment']=='Neutral')]
# Out:
#                               App  \
# 3595  Abs Training-Burn belly fat
# 3597  Abs Training-Burn belly fat
# 3602  Abs Training-Burn belly fat
# 3611  Abs Training-Burn belly fat
# 3613  Abs Training-Burn belly fat
#
#                                       Translated_Review Sentiment  \
# 3595  I would recommend anyone struggling exercise a...   Neutral
# 3597      I'm sticking literally kicked booty pain gain   Neutral
# 3602  Needs work voice tells take break voice keeps ...   Neutral
# 3611    Pop ads middle night!!! Taking phone? F*** app!   Neutral
# 3613   I day day I saw difference I went XL medium size   Neutral
#
#       Sentiment_Polarity  Sentiment_Subjectivity
# 3595                 0.0                     0.0
# 3597                 0.0                     0.0
# 3602                 0.0                     0.0
# 3611                 0.0                     0.0
# 3613                 0.0                     0.0

# %% [markdown]
# ## 14 - Extract all negative sentiment reviews for Adobe Acrobat Reader with their sentiment polarity and sentiment subjectivity.

# %%
reviews[(reviews['App'].str.contains("Adobe Acrobat Reader")) & (reviews['Sentiment']=='Negative')]
# Out:
#                        App                                  Translated_Review  \
# 4146  Adobe Acrobat Reader  Not Another Damn Cloud Account! I want another...
# 4154  Adobe Acrobat Reader  The previous versions good enough.... This upd...
# 4155  Adobe Acrobat Reader  Hey Pls update app.... I'm face issues... When...
# 4171  Adobe Acrobat Reader  Forces account password means Google knowledge...
# 4186  Adobe Acrobat Reader  Not Another Damn Cloud Account! I want another...
# 4194  Adobe Acrobat Reader  The previous versions good enough.... This upd...
# 4195  Adobe Acrobat Reader  Hey Pls update app.... I'm face issues... When...
# 4211  Adobe Acrobat Reader  Forces account password means Google knowledge...
# 4217  Adobe Acrobat Reader  Forces account password means Google knowledge...
# 4225  Adobe Acrobat Reader  Not Another Damn Cloud Account! I want another...
# 4232  Adobe Acrobat Reader  The previous versions good enough.... This upd...
# ...

# %%
cleaned_reviews=reviews
cleaned_reviews
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# ...

# %%
cleaned_reviews.to_csv('Cleaned_reviews.csv')
